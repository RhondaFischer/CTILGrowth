# %% [markdown]
# # Streaming from Twitter into local host & port for sparkStream python code to read and analyzie
#
# Run this file first, then sparkStreamWorking.pynb

# %%
import socket
import requests
import os
import json
import sys

# %%
bearer_token =''

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))


def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "(from:HealthPolicyNew OR from:INHIMSS OR from:emilycfreeman OR from:HL7IndiaTSC OR from:healthbees OR from:MEDITECHSA OR from:SWBenefitsAssoc OR from:digihealthinfo)",
        },
        {"value": "(from:DrWeidner OR from:fsgoldstein OR from:JacobChristine OR from:Lacktman OR from:healthtechdan OR from:validic OR from:drstclaire OR from:HCNowRadio)",
        },
        {"value": "(from:arwmd OR from:RBlount OR from:ReasObBob OR from:carolflagg OR from:HITMarketingPR OR from:akalali OR from:LightbeamHealth OR from:jessdamassa)",
        },
        {"value": "(from:mssoftware OR from:cflashman OR from:bkalis OR from:Slabodkin OR from:HITLABnyc OR from:HeatherLandi OR from:Julie__PHM OR from:Bossoft)",
        },
        {"value": "(from:sarahbennight OR from:ArturOlesch OR from:judithconsult OR from:sgschade OR from:anoizet OR from:lenisocial OR from:catalyst_H20 OR from:RightPatient)",
        },
        {"value": "(from:dflee30 OR from:drexdeford OR from:JulieReisetter OR from:URAC OR from:OpenHealthN OR from:mstachowiak OR from:richardbagdonas OR from:anthonynotleon)",
        },
        {"value": "(from:xealthinc OR from:drscottvinci OR from:J2Novack OR from:CNSSummit OR from:bleddyn_rees OR from:NathanGrunewald OR from:MichiEndemann OR from:markpun)",
        },
        {"value": "(from:zajctjasa OR from:ThePhiaGroup OR from:HITeaWithGrace OR from:AmendolaComm OR from:ReferralMD OR from:GIANT_health OR from:ConvergeHIS OR from:TXBGH)",
        },
        {"value": "(from:ChilmarkHIT OR from:eperakslis OR from:MollyMcCarthyRN OR from:DigitalSalutem OR from:KNBComm OR from:CCHPCA OR from:hjsoch OR from:ChiefHealthExec)",
        },
        {"value": "(from:janbeger OR from:DPoschenrieder OR from:PittHealthTech OR from:sandeepburug OR from:PatientPop OR from:andreaedurkin OR from:InterSystemsUKI OR from:hpayerintel)",
        },
        {"value": "(from:AaronMiri OR from:sandeolson OR from:MedigateLtd OR from:WarpUnited OR from:StericycleComms OR from:BillFoxMD OR from:tbaupuig OR from:RelentlesHealth)",
        },
        {"value": "(from:GlobalMed_USA OR from:wpacker_hi OR from:CTOAndITGuy OR from:PaddyPadmanabha OR from:CareInnovations OR from:PeterCoffaro OR from:Flashfuture OR from:ronnybjornevag)",
        },
        {"value": "(from:herkocoomans OR from:SueWoods OR from:EditorJeni OR from:francisww OR from:healthcora OR from:PrimeHealthCO OR from:SterlingHIT OR from:Sid_Healthcare)",
        },
        {"value": "(from:UCONNmhealth OR from:updox OR from:MargaritaShefs OR from:M_Swanfeldt OR from:ChrisSilvaDRG OR from:LeloBurti OR from:Science37x OR from:deetelecare)",
        },
        {"value": "(from:tfotis73 OR from:ErinHead_HIM OR from:PedroCanoD OR from:FDB_US OR from:aaronmartinfc OR from:MMSJennifer OR from:cristianliu OR from:connectedmed)",
        },
        {"value": "(from:khgamble OR from:sbrudnicki OR from:natarpr OR from:GeriLynn OR from:MaramMPH OR from:ThisWeekinHIT OR from:levshapiro OR from:KonicaMinoltaMI)",
        },
        {"value": "(from:AnswersNetwork OR from:HelenBurstin OR from:SiwickiHealthIT OR from:ssutner OR from:medableinc OR from:theaaih OR from:Zsu_T_Varga OR from:jsearfoss)",
        },
        {"value": "(from:medtechMarion OR from:KarenATXMH OR from:JustinCollierMD OR from:jeremycoleman OR from:byMichaelWalter OR from:PopHealthWeek OR from:biofourmis OR from:kkcorbet)",
        },
        {"value": "(from:ShelleyGilberg OR from:PEHealthIT OR from:JayGerhart OR from:cynergistek OR from:Greg_Meyer93 OR from:HlthExec OR from:LindsayDeneault OR from:Aneel_Irfan)",
        },
        {"value": "(from:Healthwise OR from:DFWBGH OR from:drjbajwa OR from:ajayprasad_ OR from:Dicompath OR from:alexanderberler OR from:HITinfrastruct OR from:JessicaKimCohen)",
        },
        {"value": "(from:ATLHealthLawyer OR from:AmanKhanna OR from:DrRafiei OR from:Datica_Inc OR from:TomCalvinJones OR from:UsmanSattarMD OR from:ConsejoSano_US OR from:FixingHCPodcast)",
        },
        {"value": "(from:StoltenbergCon OR from:kldavid OR from:SGATweet OR from:drgautamgulati OR from:Wanida_Chua OR from:Dottor_T OR from:jonastana OR from:EMJInnovations)",
        },
        {"value": "(from:HIB_Solutions OR from:dvdmena OR from:goeljasper OR from:theMFaktor OR from:DJHadersPhD OR from:digihealthinfo OR from:HealthPointDSU OR from:jwsamuel)",
        },
        {"value": "(from:krayker OR from:DonnaTECScot OR from:Experian_Health OR from:mHealthIntel OR from:OneviewHC OR from:sumeetkad OR from:AdrianAdewunmi OR from:BrianLRMan)",
        },
        {"value": "telecritical care"},


    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

    
def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

    
    
def get_stream(set, conn):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            tweet_text = json.dumps(json_response["data"]["text"])
            #print(tweet_text)
            print(json.dumps(json_response, indent=4, sort_keys=True))
            conn.sendall((tweet_text+"\n").encode("utf-8"))
            #conn.send((tweet_text+'\n').encode("utf-8"))
        
def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
def main():
    url = create_url()
    rules = get_rules()
    delete = delete_all_rules(rules)
    set = set_rules(delete)
    print("set", set)
    # server (local machine) creates listening socket
    #s = socket.socket()
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    #host = "0.0.0.0" 
    host = "127.0.0.1"
    port = 5555
    #s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
    s.bind((host, port))
    print('socket is ready')
    # server (local machine) listens for connections
    s.listen()
    print('socket is listening')
    # return the socket and the address on the other side of the connection (client side)
    c_socket, addr = s.accept()
    #c_socket.setblocking(False)
    print("Received request from: " + str(addr))
    print('start sending data from Twitter to socket')
    get_stream(set,c_socket)
    print("******data********")



if __name__ == "__main__":
    main()
# Out:
# {"data": [{"id": "1520517809255686145", "value": "(from:arwmd OR from:RBlount OR from:ReasObBob OR from:carolflagg OR from:HITMarketingPR OR from:akalali OR from:LightbeamHealth OR from:jessdamassa)"}, {"id": "1520517809255686146", "value": "(from:ShelleyGilberg OR from:PEHealthIT OR from:JayGerhart OR from:cynergistek OR from:Greg_Meyer93 OR from:HlthExec OR from:LindsayDeneault OR from:Aneel_Irfan)"}, {"id": "1520517809255686147", "value": "(from:tfotis73 OR from:ErinHead_HIM OR from:PedroCanoD OR from:FDB_US OR from:aaronmartinfc OR from:MMSJennifer OR from:cristianliu OR from:connectedmed)"}, {"id": "1520517809255686148", "value": "(from:StoltenbergCon OR from:kldavid OR from:SGATweet OR from:drgautamgulati OR from:Wanida_Chua OR from:Dottor_T OR from:jonastana OR from:EMJInnovations)"}, {"id": "1520517809255686149", "value": "telecritical care"}, {"id": "1520517809255686150", "value": "(from:AnswersNetwork OR from:HelenBurstin OR from:SiwickiHealthIT OR from:ssutner OR from:meda
# ...

# %% [markdown]
# # Rules
#
#     {"value": "hurricane OR earthquake", "lang": "EN", "place_country":"US",
#         "tag": "theme:info has:geo original from weather agencies and gauges"},
#         {"value": "disaster has:images"},
